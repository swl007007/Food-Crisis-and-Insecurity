# %%
import rasterio
import geopandas as gpd
from rasterio.mask import mask
import os
import tqdm
import rasterio.features
from shapely.geometry import shape
import pandas as pd


os.chdir(r'C:\Users\WeilunShi\OneDrive - CGIAR\Desktop\Food Crisis and Insecurity\\1.Initilization\downloads')

#filter the raster files
raster_files = [f for f in os.listdir() if f.endswith('.tif')]

fourth_index = len(raster_files) // 4
middle_index = len(raster_files) // 2
three_fourth_index = len(raster_files) // 4 * 3

raster_files = raster_files[three_fourth_index:]

#create a empty geodataframe to store the results
results = gpd.GeoDataFrame()
shp_file = '../unique_polygons_shapefile.shp'
gdf_mask = gpd.read_file(shp_file)
gdf_mask = gdf_mask.to_crs("EPSG:4326")
#loop through the raster files


for raster_file in tqdm.tqdm(raster_files):
    # Read the raster file (.tif)
    src = rasterio.open(raster_file)
    # Get the geometry of the shapefile as GeoJSON
    mask_geom = gdf_mask.geometry


    def raster_to_polygons(raster_array, transform, nodata=None):
        polygons = []
        for vec, val in rasterio.features.shapes(raster_array, mask=raster_array != nodata, transform=transform):
            if val != nodata:
                polygons.append({"geometry": shape(vec), "value": val})
        return polygons

    # Mask the raster using the geometry
    out_image, out_transform = mask(src, mask_geom, crop=True, filled=False)
    out_meta = src.meta.copy()
    out_meta.update({"driver": "GTiff",
                    "height": out_image.shape[1],
                    "width": out_image.shape[2],
                    "transform": out_transform})
    polygons = raster_to_polygons(out_image[0], out_transform)
    # Create a GeoDataFrame from the polygons
    gdf = gpd.GeoDataFrame(polygons, crs=out_meta["crs"])

    # Set a new index if desired
    result = gdf.reset_index().rename(columns={0: 'value'})


    # rename the column,set name
    result.rename(columns={'index':'ID','value':'GOSIF_GPP'},inplace=True)


    # Perform a spatial join between the points and polygons
    spatial_join_gdf = gpd.sjoin(result, gdf_mask, how='inner', op='within')

    # Group by the 'polygon_id' column and calculate the mean of the 'value' column
    aggregated_gdf = spatial_join_gdf.groupby('FID').agg({'GOSIF_GPP': 'mean'}).reset_index()

    # join aggregated_gdf with gdf_mask on FID
    aggregated_gdf = gdf_mask.merge(aggregated_gdf, on='FID', how='left')

    # add a column to indicate the raster file
    aggregated_gdf['time'] = raster_file  
    
    #append the results to the geodataframe
    results = pd.concat([results, aggregated_gdf], ignore_index=True, axis=0)




# output the results as geojson file
results.to_file('GOSIF_GPP_4.geojson', driver='GeoJSON')
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#   6%|▌         | 1/18 [00:57<16:09, 57.02s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  11%|█         | 2/18 [01:56<15:39, 58.69s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  17%|█▋        | 3/18 [02:56<14:44, 58.94s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  22%|██▏       | 4/18 [03:58<14:03, 60.26s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  28%|██▊       | 5/18 [05:02<13:23, 61.79s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  33%|███▎      | 6/18 [06:08<12:37, 63.12s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  39%|███▉      | 7/18 [07:15<11:49, 64.48s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  44%|████▍     | 8/18 [08:19<10:43, 64.35s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  50%|█████     | 9/18 [09:23<09:37, 64.11s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  56%|█████▌    | 10/18 [10:23<08:22, 62.77s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  61%|██████    | 11/18 [11:23<07:13, 61.94s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  67%|██████▋   | 12/18 [12:24<06:10, 61.81s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  72%|███████▏  | 13/18 [13:29<05:13, 62.63s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  78%|███████▊  | 14/18 [14:34<04:13, 63.32s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  83%|████████▎ | 15/18 [15:40<03:12, 64.06s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  89%|████████▉ | 16/18 [16:47<02:09, 64.95s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  94%|█████████▍| 17/18 [17:51<01:04, 64.93s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# 100%|██████████| 18/18 [18:56<00:00, 63.15s/it]

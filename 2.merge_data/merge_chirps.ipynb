# %%
import rasterio
import geopandas as gpd
from rasterio.mask import mask
import os
import tqdm
import rasterio.features
from shapely.geometry import shape
import pandas as pd


os.chdir(r'C:\Users\WeilunShi\OneDrive - CGIAR\Desktop\Food Crisis and Insecurity\downloads_chirps')

#filter the raster files
raster_files = [f for f in os.listdir() if f.endswith('.tif')]

fourth_index = len(raster_files) // 4
middle_index = len(raster_files) // 2
three_fourth_index = len(raster_files) // 4 * 3

raster_files = raster_files[three_fourth_index:]

#create a empty geodataframe to store the results
results = gpd.GeoDataFrame()
shp_file = '../1.Initilization/unique_polygons_shapefile.shp'
gdf_mask = gpd.read_file(shp_file)
gdf_mask = gdf_mask.to_crs("EPSG:4326")
#loop through the raster files


for raster_file in tqdm.tqdm(raster_files):
    # Read the raster file (.tif)
    src = rasterio.open(raster_file)
    # Get the geometry of the shapefile as GeoJSON
    mask_geom = gdf_mask.geometry


    def raster_to_polygons(raster_array, transform, nodata=None):
        polygons = []
        for vec, val in rasterio.features.shapes(raster_array, mask=raster_array != nodata, transform=transform):
            if val != nodata:
                polygons.append({"geometry": shape(vec), "value": val})
        return polygons

    # Mask the raster using the geometry
    out_image, out_transform = mask(src, mask_geom, crop=True, filled=False)
    out_meta = src.meta.copy()
    out_meta.update({"driver": "GTiff",
                    "height": out_image.shape[1],
                    "width": out_image.shape[2],
                    "transform": out_transform})
    polygons = raster_to_polygons(out_image[0], out_transform)
    # Create a GeoDataFrame from the polygons
    gdf = gpd.GeoDataFrame(polygons, crs=out_meta["crs"])

    # Set a new index if desired
    result = gdf.reset_index().rename(columns={0: 'value'})


    # Perform a spatial join between the points and polygons
    spatial_join_gdf = gpd.sjoin(result, gdf_mask, how='inner', op='within')

    # Group by the 'polygon_id' column and calculate the mean of the 'value' column
    aggregated_gdf = spatial_join_gdf.groupby('FID').agg({'value': 'mean'}).reset_index()

    # join aggregated_gdf with gdf_mask on FID
    aggregated_gdf = gdf_mask.merge(aggregated_gdf, on='FID', how='left')

    # add a column to indicate the raster file
    aggregated_gdf['time'] = raster_file  
    
    #append the results to the geodataframe
    results = pd.concat([results, aggregated_gdf], ignore_index=True, axis=0)




# output the results as geojson file
results.to_file('chirps_4.geojson', driver='GeoJSON')
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#   6%|▌         | 1/18 [01:09<19:42, 69.55s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  11%|█         | 2/18 [02:19<18:39, 69.96s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  17%|█▋        | 3/18 [03:30<17:36, 70.40s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  22%|██▏       | 4/18 [04:41<16:26, 70.50s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  28%|██▊       | 5/18 [05:52<15:19, 70.72s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  33%|███▎      | 6/18 [07:02<14:06, 70.55s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  39%|███▉      | 7/18 [08:17<13:12, 72.09s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  44%|████▍     | 8/18 [09:40<12:34, 75.45s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  50%|█████     | 9/18 [10:56<11:19, 75.49s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  56%|█████▌    | 10/18 [12:08<09:56, 74.55s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  61%|██████    | 11/18 [13:19<08:33, 73.41s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  67%|██████▋   | 12/18 [14:30<07:15, 72.59s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  72%|███████▏  | 13/18 [15:40<06:00, 72.01s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  78%|███████▊  | 14/18 [16:51<04:46, 71.67s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  83%|████████▎ | 15/18 [18:01<03:33, 71.04s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  89%|████████▉ | 16/18 [19:11<02:21, 70.73s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#  94%|█████████▍| 17/18 [20:21<01:10, 70.60s/it]c:\Users\WeilunShi\.virtualenvs\Food_Crisis_and_Insecurity-8fC6jjVv\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# 100%|██████████| 18/18 [21:32<00:00, 71.80s/it]

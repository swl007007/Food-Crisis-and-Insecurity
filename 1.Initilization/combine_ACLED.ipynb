# %%
import pandas as pd
import numpy as np

df = pd.read_csv('..\\0.external_data\\ACLED_data\\2017-01-01-2019-12-31-Caribbean-Caucasus_and_Central_Asia-Central_America-Eastern_Africa-Middle_Africa-Middle_East-South_Asia-Southern_Africa-Western_Africa.csv')
df2 = pd.read_csv('..\\0.external_data\\ACLED_data\\2020-01-01-2022-12-31-Caribbean-Caucasus_and_Central_Asia-Central_America-Eastern_Africa-Middle_Africa-Middle_East-South_Asia-Southern_Africa-Western_Africa.csv')

df = pd.concat([df, df2])

df.to_csv("ACLED.csv", sep='\t', encoding='utf-8')
# Out:
#   event_id_cnty        event_date  year  time_precision       disorder_type
# 0       IRN5919  31 December 2019  2019               1      Demonstrations  \
# 1      YEM45958  31 December 2019  2019               1  Political violence
# 2      YEM45959  31 December 2019  2019               1  Political violence
# 3      YEM45962  31 December 2019  2019               1  Political violence
# 4      YEM45963  31 December 2019  2019               1  Political violence
#
#                    event_type                     sub_event_type
# 0                    Protests                   Peaceful protest  \
# 1  Explosions/Remote violence  Shelling/artillery/missile attack
# 2  Explosions/Remote violence  Shelling/artillery/missile attack
# 3  Explosions/Remote violence  Shelling/artillery/missile attack
# 4                     Battles                        Armed clash
#
#                                               actor1
# 0                                  Protesters (Iran)  \
# ...

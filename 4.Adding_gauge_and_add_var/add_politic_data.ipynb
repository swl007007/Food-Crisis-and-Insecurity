# %%
import numpy as np
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# import new_merge.csv
df_new = pd.read_csv('merge_complete_elevation.csv')
# see unique countries
df_new['country'].unique()
# delete elevation_x and soil column, rename elevatrion_y to elevation
df_new = df_new.drop(['elevation_x', 'soil'], axis=1)
df_new = df_new.rename(columns={'elevation_y': 'elevation'})
# extract unique lat and lon
location = df_new.drop_duplicates(subset=['lat', 'lon'])
# subset only include lat and lon
location = location[['lat', 'lon']]

# %%
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import tqdm
import time

def requests_retry_session(
    retries=3,
    backoff_factor=0.3,
    status_forcelist=(500, 502, 504),
    session=None,
):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

# %%
# create a new df to store the data
result = pd.DataFrame(columns=[ 'lat', 'lon', 'country', 'state','country_code','address'])

# loop through each lat and lon
for i in tqdm.tqdm(range(len(location))):
    # request the data from the API
    url = 'https://geocode.maps.co/reverse?lat=' + str(location['lat'].iloc[i]) + '&lon=' + str(location['lon'].iloc[i]) 
    try:
        response = requests_retry_session().get(url)
        response.raise_for_status()
    except requests.exceptions.HTTPError as errh:
        print ("Http Error:",errh)
    except requests.exceptions.ConnectionError as errc:
        print ("Error Connecting:",errc)
    except requests.exceptions.Timeout as errt:
        print ("Timeout Error:",errt)
    except requests.exceptions.RequestException as err:
        print ("OOps: Something Else",err)
    data = response.json()
    # create a new df to store the data
    df = pd.DataFrame(columns=['lat', 'lon', 'country', 'state','country_code','address'])
    # extract time and temperature_2m_mean from the json file
    df.loc[i,'country'] = data['address']['country']
    if 'state' in data['address']:
        df.loc[i,'state'] = data['address']['state']
    else:
        df.loc[i,'state'] = ''
    df.loc[i,'country_code'] = data['address']['country_code']
    df.loc[i,'address'] = data['display_name']
    df.loc[i,'lat'] = location['lat'].iloc[i]
    df.loc[i,'lon'] = location['lon'].iloc[i]
    df.columns = ['lat', 'lon', 'country', 'state','country_code','address']
    # concat the data
    result = pd.concat([result, df], axis=0)
    # sleep for 1 second
    time.sleep(0.5)
# Out:
# 100%|██████████| 1878/1878 [17:24<00:00,  1.80it/s]

# %%
import pycountry
def get_country_name(code):
    country = pycountry.countries.get(alpha_2=code)
    if country:
        return country.name
    else:
        return None

# %%
result['country_code'].unique()
# Out:
# array(['cd', 'cf', 'na', 'za', 'ss', 'bi', 'zw', 'ug', 'sd', 'mz', 'lb',
#        'ke', 'et', 'so', 'ye', 'mg', 'af', 'pk', 'tj', 'zm', 'ls', 'tz',
#        'mw', 'hn', 'sv', 'gt', 'ht', 'sz', 'do', 'ao', 'dj'], dtype=object)

# %%
# capitalise the country_code
result['country_code'] = result['country_code'].str.upper()

# apply get_country_name function to country_code column
result['country_en'] = result['country_code'].apply(get_country_name)

# %%
result.country_en.unique()
# Out:
# array(['Congo, The Democratic Republic of the',
#        'Central African Republic', 'Namibia', 'South Africa',
#        'South Sudan', 'Burundi', 'Zimbabwe', 'Uganda', 'Sudan',
#        'Mozambique', 'Lebanon', 'Kenya', 'Ethiopia', 'Somalia', 'Yemen',
#        'Madagascar', 'Afghanistan', 'Pakistan', 'Tajikistan', 'Zambia',
#        'Lesotho', 'Tanzania, United Republic of', 'Malawi', 'Honduras',
#        'El Salvador', 'Guatemala', 'Haiti', 'Eswatini',
#        'Dominican Republic', 'Angola', 'Djibouti'], dtype=object)

# %%
# see columns of df
df_new.columns
# Out:
# Index(['date', 'event_count_battles', 'event_count_explosions',
#        'event_count_violence', 'fatalities_battles', 'fatalities_explosions',
#        'fatalities_violence', 'GOSIF_GPP', 'rainfall_chirps', 'GOSIF_GPP_SD',
#        'lon', 'lat', 'temperature_2m_mean', 'temperature_2m_mean_sd',
#        'shortwave_radiation_sum', 'shortwave_radiation_sum_sd',
#        'precipitation_sum', 'precipitation_sum_sd',
#        'nearest_neighbor_distance_x', 'market_lat', 'market_lon',
#        'price_index', 'estimated_population', 'title', 'overall_phase',
#        'country', 'phase3_worse_population', 'phase3_worse_percentage',
#        'phase1_population', 'phase1_percent', 'phase2_population',
#        'phase2_percent', 'phase3_population', 'phase3_percent',
#        'phase4_population', 'phase4_percent', 'phase5_population',
#        'phase5_percent', 'phase3_worse_percentage_manual',
#        'phase3_plus_phase4', 'phase2_worse_percentage_manual',
#        'phase2_plus_phase3', 'phase2_plus_phase3_plus_phase4',
#        'soil_moisture_0_to_7cm_mean', 'soil_moisture_0_to_7cm_sd',
#        'elevation'],
#       dtype='object')

# %%
# rename nearest_neigbor_distance_x to distance, drop title and country
df_new = df_new.drop(['title', 'country'], axis=1)

# %%
# merge df_new and result, add indicator column
df_new = pd.merge(df_new, result, how='left', on=['lat', 'lon'], indicator=True)

# %%
df_new._merge.value_counts()
# Out:
# _merge
# both          38776
# left_only         0
# right_only        0
# Name: count, dtype: int64

# %%
# drop _merge
df_new = df_new.drop(['_merge'], axis=1)

# %%
# set display column to 100
pd.set_option('display.max_columns', 100)

# %%
df_new.head()
# Out:
#          date  event_count_battles  event_count_explosions
# 0  2017-01-01                  1.0                     0.0  \
# 1  2017-01-01                  1.0                     0.0
# 2  2017-01-01                  1.0                     0.0
# 3  2017-01-01                  2.0                     0.0
# 4  2017-01-01                  1.0                     0.0
#
#    event_count_violence  fatalities_battles  fatalities_explosions
# 0                   0.0                 5.0                    0.0  \
# 1                   0.0                 5.0                    0.0
# 2                   0.0                 5.0                    0.0
# 3                   0.0                 4.0                    0.0
# 4                   0.0                 3.0                    0.0
#
#    fatalities_violence     GOSIF_GPP  rainfall_chirps  GOSIF_GPP_SD
# 0                  0.0  22458.920383       109.417561   1198.248826  \
# 1                  0.0  22200.090910       111.121122   1175.474359
# 2                  0.0  22218.324112       138.828427   1342.802136
# 3                  0.0   4970.260394         0.229789   1425.793103
# 4                  0.0   4307.993754         0.134368   1467.055556
#
#          lon       lat  temperature_2m_mean  temperature_2m_mean_sd
# 0  14.070903 -5.533893            26.122581                0.804450  \
# 1  14.068317 -5.493558            25.922581                0.804450
# 2  14.314904 -5.289988            26.306452                0.817286
# 3  15.778695  6.765411            25.380645                1.135318
# 4  16.437358  7.248169            26.880645                1.486252
#
#    shortwave_radiation_sum  shortwave_radiation_sum_sd  precipitation_sum
# 0                      NaN                         NaN           4.238710  \
# 1                17.102903                    3.211451           4.238710
# 2                17.347742                    3.216938           4.277419
# 3                22.995806                    1.004940           0.000000
# 4                22.840968                    0.772474           0.000000
#
#    precipitation_sum_sd  nearest_neighbor_distance_x  market_lat  market_lon
# 0              5.574925                   379.143546       -8.84       13.23  \
# 1              5.574925                   383.425920       -8.84       13.23
# 2              5.246822                   412.492874       -8.84       13.23
# 3              0.000000                   203.212588        8.57       16.07
# 4              0.000000                   152.447655        8.57       16.07
#
#    price_index  estimated_population  overall_phase  phase3_worse_population
# 0   130.034171                   NaN            NaN                      NaN  \
# 1   130.034171                   NaN            NaN                      NaN
# 2   130.034171                   NaN            NaN                      NaN
# 3    53.106102                   NaN            NaN                      NaN
# 4    53.106102                   NaN            NaN                      NaN
#
#    phase3_worse_percentage  phase1_population  phase1_percent
# 0                      NaN                NaN             NaN  \
# 1                      NaN                NaN             NaN
# 2                      NaN                NaN             NaN
# 3                      NaN                NaN             NaN
# 4                      NaN                NaN             NaN
#
#    phase2_population  phase2_percent  phase3_population  phase3_percent
# 0                NaN             NaN                NaN             NaN  \
# 1                NaN             NaN                NaN             NaN
# 2                NaN             NaN                NaN             NaN
# 3                NaN             NaN                NaN             NaN
# 4                NaN             NaN                NaN             NaN
#
#    phase4_population  phase4_percent  phase5_population  phase5_percent
# 0                NaN             NaN                NaN             NaN  \
# 1                NaN             NaN                NaN             NaN
# 2                NaN             NaN                NaN             NaN
# 3                NaN             NaN                NaN             NaN
# 4                NaN             NaN                NaN             NaN
#
#    phase3_worse_percentage_manual  phase3_plus_phase4
# 0                             NaN                 NaN  \
# 1                             NaN                 NaN
# 2                             NaN                 NaN
# 3                             NaN                 NaN
# 4                             NaN                 NaN
#
#    phase2_worse_percentage_manual  phase2_plus_phase3
# 0                             NaN                 NaN  \
# 1                             NaN                 NaN
# 2                             NaN                 NaN
# 3                             NaN                 NaN
# 4                             NaN                 NaN
#
#    phase2_plus_phase3_plus_phase4  soil_moisture_0_to_7cm_mean
# 0                             NaN                     0.451499  \
# 1                             NaN                     0.451499
# 2                             NaN                     0.459875
# 3                             NaN                     0.165539
# 4                             NaN                     0.139403
#
#    soil_moisture_0_to_7cm_sd  elevation
# 0                   0.027810      283.0  \
# 1                   0.027810      332.0
# 2                   0.025151      293.0
# 3                   0.000659      886.0
# 4                   0.000695      602.0
#
#                                              country          state
# 0                   République démocratique du Congo  Kongo-Central  \
# 1                   République démocratique du Congo  Kongo-Central
# 2                   République démocratique du Congo  Kongo-Central
# 3  Ködörösêse tî Bêafrîka - République Centrafric...    Ouham-Pendé
# 4  Ködörösêse tî Bêafrîka - République Centrafric...    Ouham-Pendé
#
#   country_code                                            address
# 0           CD  Songololo, Kongo-Central, République démocrati...  \
# 1           CD  Kwanza, Songololo, Kongo-Central, République d...
# 2           CD  Songololo, Kongo-Central, République démocrati...
# 3           CF  Ouham-Pendé, Ködörösêse tî Bêafrîka - Républiq...
# 4           CF  Paoua, Ouham-Pendé, Ködörösêse tî Bêafrîka - R...
#
#                               country_en
# 0  Congo, The Democratic Republic of the
# 1  Congo, The Democratic Republic of the
# 2  Congo, The Democratic Republic of the
# 3               Central African Republic
# 4               Central African Republic

# %%
df_new.columns
# Out:
# Index(['date', 'event_count_battles', 'event_count_explosions',
#        'event_count_violence', 'fatalities_battles', 'fatalities_explosions',
#        'fatalities_violence', 'GOSIF_GPP', 'rainfall_chirps', 'GOSIF_GPP_SD',
#        'lon', 'lat', 'temperature_2m_mean', 'temperature_2m_mean_sd',
#        'shortwave_radiation_sum', 'shortwave_radiation_sum_sd',
#        'precipitation_sum', 'precipitation_sum_sd',
#        'nearest_neighbor_distance_x', 'market_lat', 'market_lon',
#        'price_index', 'estimated_population', 'overall_phase',
#        'phase3_worse_population', 'phase3_worse_percentage',
#        'phase1_population', 'phase1_percent', 'phase2_population',
#        'phase2_percent', 'phase3_population', 'phase3_percent',
#        'phase4_population', 'phase4_percent', 'phase5_population',
#        'phase5_percent', 'phase3_worse_percentage_manual',
#        'phase3_plus_phase4', 'phase2_worse_percentage_manual',
#        'phase2_plus_phase3', 'phase2_plus_phase3_plus_phase4',
#        'soil_moisture_0_to_7cm_mean', 'soil_moisture_0_to_7cm_sd', 'elevation',
#        'country', 'state', 'country_code', 'address', 'country_en'],
#       dtype='object')

# %%
# reorder the columns
df_new = df_new.rename(columns={'nearest_neighbor_distance_x': 'distance'})
df_new = df_new[['date','country','country_en','state','address','country_code','lon', 'lat','overall_phase',
       'phase3_worse_population', 'phase3_worse_percentage',
       'phase1_population', 'phase1_percent', 'phase2_population',
       'phase2_percent', 'phase3_population', 'phase3_percent',
       'phase4_population', 'phase4_percent', 'phase5_population',
       'phase5_percent', 'phase3_worse_percentage_manual',
       'phase3_plus_phase4', 'phase2_worse_percentage_manual',
       'phase2_plus_phase3', 'phase2_plus_phase3_plus_phase4','event_count_battles', 'event_count_explosions',
       'event_count_violence', 'fatalities_battles', 'fatalities_explosions',
       'fatalities_violence', 'GOSIF_GPP', 'rainfall_chirps', 'GOSIF_GPP_SD',
       'temperature_2m_mean', 'temperature_2m_mean_sd',
       'shortwave_radiation_sum', 'shortwave_radiation_sum_sd',
       'precipitation_sum', 'precipitation_sum_sd','soil_moisture_0_to_7cm_mean', 'soil_moisture_0_to_7cm_sd', 'elevation','distance', 'market_lat', 'market_lon',
       'price_index', 'estimated_population']]

# %%
df_new
# Out:
#              date                                            country
# 0      2017-01-01                   République démocratique du Congo  \
# 1      2017-01-01                   République démocratique du Congo
# 2      2017-01-01                   République démocratique du Congo
# 3      2017-01-01  Ködörösêse tî Bêafrîka - République Centrafric...
# 4      2017-01-01  Ködörösêse tî Bêafrîka - République Centrafric...
# ...           ...                                                ...
# 38771  2022-12-01                                         Тоҷикистон
# 38772  2022-12-01                                          افغانستان
# 38773  2022-12-01                                            پاکستان
# 38774  2022-12-01                                            پاکستان
# 38775  2022-12-01                                          افغانستان
#
#                                   country_en
# 0      Congo, The Democratic Republic of the  \
# 1      Congo, The Democratic Republic of the
# 2      Congo, The Democratic Republic of the
# 3                   Central African Republic
# 4                   Central African Republic
# ...                                      ...
# 38771                             Tajikistan
# 38772                            Afghanistan
# 38773                               Pakistan
# 38774                               Pakistan
# 38775                            Afghanistan
#
#                                     state
# 0                           Kongo-Central  \
# 1                           Kongo-Central
# 2                           Kongo-Central
# 3                             Ouham-Pendé
# 4                             Ouham-Pendé
# ...                                   ...
# 38771  Вилояти Мухтори Кӯҳистони Бадахшон
# 38772                          کونړ ولايت
# 38773                       خیبر پښتونخوا
# 38774                       خیبر پښتونخوا
# 38775                          کونړ ولايت
#
#                                                  address country_code
# 0      Songololo, Kongo-Central, République démocrati...           CD  \
# 1      Kwanza, Songololo, Kongo-Central, République d...           CD
# 2      Songololo, Kongo-Central, République démocrati...           CD
# 3      Ouham-Pendé, Ködörösêse tî Bêafrîka - Républiq...           CF
# 4      Paoua, Ouham-Pendé, Ködörösêse tî Bêafrîka - R...           CF
# ...                                                  ...          ...
# 38771  РБ06, Қозидеҳ, Ноҳияи Ишкошим, Вилояти Мухтори...           TJ
# 38772          ناړی, ناړۍ ولسوالۍ, کونړ ولايت, افغانستان           AF
# 38773                 خار, باجوړ, خیبر پښتونخوا, پاکستان           PK
# 38774                 خار, باجوړ, خیبر پښتونخوا, پاکستان           PK
# 38775             وټه پور ولسوالۍ, کونړ ولايت, افغانستان           AF
#
#              lon        lat  overall_phase  phase3_worse_population
# 0      14.070903  -5.533893            NaN                      NaN  \
# 1      14.068317  -5.493558            NaN                      NaN
# 2      14.314904  -5.289988            NaN                      NaN
# 3      15.778695   6.765411            NaN                      NaN
# 4      16.437358   7.248169            NaN                      NaN
# ...          ...        ...            ...                      ...
# 38771  71.456211   37.03783            NaN                      NaN
# 38772  71.487215  35.171917            NaN                      NaN
# 38773   71.50496  34.752987            NaN                      NaN
# 38774  71.504927  34.753595            NaN                      NaN
# 38775  71.093973  34.965992            NaN                      NaN
#
#        phase3_worse_percentage  phase1_population  phase1_percent
# 0                          NaN                NaN             NaN  \
# 1                          NaN                NaN             NaN
# 2                          NaN                NaN             NaN
# 3                          NaN                NaN             NaN
# 4                          NaN                NaN             NaN
# ...                        ...                ...             ...
# 38771                      NaN                NaN             NaN
# 38772                      NaN                NaN             NaN
# 38773                      NaN                NaN             NaN
# 38774                      NaN                NaN             NaN
# 38775                      NaN                NaN             NaN
#
#        phase2_population  phase2_percent  phase3_population  phase3_percent
# 0                    NaN             NaN                NaN             NaN  \
# 1                    NaN             NaN                NaN             NaN
# 2                    NaN             NaN                NaN             NaN
# 3                    NaN             NaN                NaN             NaN
# 4                    NaN             NaN                NaN             NaN
# ...                  ...             ...                ...             ...
# 38771                NaN             NaN                NaN             NaN
# 38772                NaN             NaN                NaN             NaN
# 38773                NaN             NaN                NaN             NaN
# 38774                NaN             NaN                NaN             NaN
# 38775                NaN             NaN                NaN             NaN
#
#        phase4_population  phase4_percent  phase5_population  phase5_percent
# 0                    NaN             NaN                NaN             NaN  \
# 1                    NaN             NaN                NaN             NaN
# 2                    NaN             NaN                NaN             NaN
# 3                    NaN             NaN                NaN             NaN
# 4                    NaN             NaN                NaN             NaN
# ...                  ...             ...                ...             ...
# 38771                NaN             NaN                NaN             NaN
# 38772                NaN             NaN                NaN             NaN
# 38773                NaN             NaN                NaN             NaN
# 38774                NaN             NaN                NaN             NaN
# 38775                NaN             NaN                NaN             NaN
#
#        phase3_worse_percentage_manual  phase3_plus_phase4
# 0                                 NaN                 NaN  \
# 1                                 NaN                 NaN
# 2                                 NaN                 NaN
# 3                                 NaN                 NaN
# 4                                 NaN                 NaN
# ...                               ...                 ...
# 38771                             NaN                 NaN
# 38772                             NaN                 NaN
# 38773                             NaN                 NaN
# 38774                             NaN                 NaN
# 38775                             NaN                 NaN
#
#        phase2_worse_percentage_manual  phase2_plus_phase3
# 0                                 NaN                 NaN  \
# 1                                 NaN                 NaN
# 2                                 NaN                 NaN
# 3                                 NaN                 NaN
# 4                                 NaN                 NaN
# ...                               ...                 ...
# 38771                             NaN                 NaN
# 38772                             NaN                 NaN
# 38773                             NaN                 NaN
# 38774                             NaN                 NaN
# 38775                             NaN                 NaN
#
#        phase2_plus_phase3_plus_phase4  event_count_battles
# 0                                 NaN                  1.0  \
# 1                                 NaN                  1.0
# 2                                 NaN                  1.0
# 3                                 NaN                  2.0
# 4                                 NaN                  1.0
# ...                               ...                  ...
# 38771                             NaN                  0.0
# 38772                             NaN                  1.0
# 38773                             NaN                  1.0
# 38774                             NaN                  1.0
# 38775                             NaN                  2.0
#
#        event_count_explosions  event_count_violence  fatalities_battles
# 0                         0.0                   0.0                 5.0  \
# 1                         0.0                   0.0                 5.0
# 2                         0.0                   0.0                 5.0
# 3                         0.0                   0.0                 4.0
# 4                         0.0                   0.0                 3.0
# ...                       ...                   ...                 ...
# 38771                     1.0                   0.0                 0.0
# 38772                     0.0                   0.0                 0.0
# 38773                     1.0                   1.0                 1.0
# 38774                     1.0                   1.0                 1.0
# 38775                     1.0                   0.0                 2.0
#
#        fatalities_explosions  fatalities_violence     GOSIF_GPP
# 0                        0.0                  0.0  22458.920383  \
# 1                        0.0                  0.0  22200.090910
# 2                        0.0                  0.0  22218.324112
# 3                        0.0                  0.0   4970.260394
# 4                        0.0                  0.0   4307.993754
# ...                      ...                  ...           ...
# 38771                    3.0                  0.0    784.389728
# 38772                    0.0                  0.0   1252.600815
# 38773                    0.0                  1.0   1416.164120
# 38774                    0.0                  1.0   1467.059042
# 38775                    2.0                  0.0   1182.615838
#
#        rainfall_chirps  GOSIF_GPP_SD  temperature_2m_mean
# 0           109.417561   1198.248826            26.122581  \
# 1           111.121122   1175.474359            25.922581
# 2           138.828427   1342.802136            26.306452
# 3             0.229789   1425.793103            25.380645
# 4             0.134368   1467.055556            26.880645
# ...                ...           ...                  ...
# 38771        10.718039   1692.512253           -10.670968
# 38772        13.004443   1651.941176             6.951613
# 38773         9.017693   1422.424242             9.309677
# 38774         9.080978   1422.424242             9.309677
# 38775         8.646097   1561.464286             9.309677
#
#        temperature_2m_mean_sd  shortwave_radiation_sum
# 0                    0.804450                      NaN  \
# 1                    0.804450                17.102903
# 2                    0.817286                17.347742
# 3                    1.135318                22.995806
# 4                    1.486252                22.840968
# ...                       ...                      ...
# 38771                3.213741                10.735161
# 38772                1.597054                10.958387
# 38773                1.784630                11.210000
# 38774                1.784630                11.210000
# 38775                1.682529                11.095484
#
#        shortwave_radiation_sum_sd  precipitation_sum  precipitation_sum_sd
# 0                             NaN           4.238710              5.574925  \
# 1                        3.211451           4.238710              5.574925
# 2                        3.216938           4.277419              5.246822
# 3                        1.004940           0.000000              0.000000
# 4                        0.772474           0.000000              0.000000
# ...                           ...                ...                   ...
# 38771                    1.558302           0.622581              1.295302
# 38772                    1.877639           0.296774              1.295244
# 38773                    1.876703           0.238710              0.872421
# 38774                    1.876703           0.238710              0.872421
# 38775                    1.911660           0.254839              0.861332
#
#        soil_moisture_0_to_7cm_mean  soil_moisture_0_to_7cm_sd  elevation
# 0                         0.451499                   0.027810      283.0  \
# 1                         0.451499                   0.027810      332.0
# 2                         0.459875                   0.025151      293.0
# 3                         0.165539                   0.000659      886.0
# 4                         0.139403                   0.000695      602.0
# ...                            ...                        ...        ...
# 38771                     0.235483                   0.006302     2625.0
# 38772                     0.283281                   0.011201     1163.0
# 38773                     0.214188                   0.012498      926.0
# 38774                     0.249997                   0.013454      911.0
# 38775                     0.241641                   0.013840     1131.0
#
#          distance  market_lat  market_lon  price_index  estimated_population
# 0      379.143546       -8.84       13.23   130.034171                   NaN
# 1      383.425920       -8.84       13.23   130.034171                   NaN
# 2      412.492874       -8.84       13.23   130.034171                   NaN
# 3      203.212588        8.57       16.07    53.106102                   NaN
# 4      152.447655        8.57       16.07    53.106102                   NaN
# ...           ...         ...         ...          ...                   ...
# 38771   52.205131       37.50       71.56    92.798223                   NaN
# 38772  130.400744       34.00       71.54   106.911393                   NaN
# 38773   83.790062       34.00       71.54   106.911393                   NaN
# 38774   83.857774       34.00       71.54   106.911393                   NaN
# 38775  114.929740       34.00       71.54   106.911393                   NaN
#
# [38776 rows x 49 columns]

# %%
# save as csv
df_new.to_csv('new_merged_dataset.csv', index=False)
